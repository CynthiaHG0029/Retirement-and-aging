# %%
import pandas as pd

# %%
fec = pd.read_excel("./cpv2020_b_eum_02_fecundidad.xlsx", sheet_name=2,  header=5,)

# %%
fec
# Out:
#                                     Entidad federativa  \
# 0                                                  NaN
# 1                                                  NaN
# 2                             Estados Unidos Mexicanos
# 3                             Estados Unidos Mexicanos
# 4                             Estados Unidos Mexicanos
# ..                                                 ...
# 562                                       32 Zacatecas
# 563                                                NaN
# 564  1 Comprende a las mujeres que no especificaron...
# 565  2 Excluye a las mujeres que no especificaron s...
# 566  3 Es la relación del total de hijas e hijos na...
#
#     Grupos quinquenales de edad  Población femenina de 12 años y más  \
# 0                           NaN                                  NaN
# 1                           NaN                                  NaN
# 2                         Total                           51962264.0
# ...

# %%
fec["Grupos quinquenales de edad"].unique()
# Out:
# array([nan, 'Total', '12-14 años', '15-19 años', '20-24 años',
#        '25-29 años', '30-34 años', '35-39 años', '40-44 años',
#        '45-49 años', '50-54 años', '55-59 años', '60-64 años',
#        '65-69 años', '70-74 años', '75-79 años', '80-84 años',
#        '85 años y más'], dtype=object)

# %%
fec_edad = fec[fec["Grupos quinquenales de edad"]=='30-34 años']

# %%
fec_edad
# Out:
#                      Entidad federativa Grupos quinquenales de edad  \
# 7              Estados Unidos Mexicanos                  30-34 años
# 24                    01 Aguascalientes                  30-34 años
# 41                   02 Baja California                  30-34 años
# 58               03 Baja California Sur                  30-34 años
# 75                          04 Campeche                  30-34 años
# 92              05 Coahuila de Zaragoza                  30-34 años
# 109                           06 Colima                  30-34 años
# 126                          07 Chiapas                  30-34 años
# 143                        08 Chihuahua                  30-34 años
# 160                 09 Ciudad de México                  30-34 años
# 177                          10 Durango                  30-34 años
# 194                       11 Guanajuato                  30-34 años
# 211                         12 Guerrero                  30-34 años
# ...

# %%
fec_cd = fec_edad[fec_edad["Entidad federativa"]=="09 Ciudad de México"]

# %%
fec_cd
# Out:
#       Entidad federativa Grupos quinquenales de edad  \
# 160  09 Ciudad de México                  30-34 años
#
#      Población femenina de 12 años y más  \
# 160                             380163.0
#
#      Número de hijas e hijos nacidos vivos  Unnamed: 4  Unnamed: 5  \
# 160                               154240.0     86469.0     89825.0
#
#      Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 160     37803.0      8564.0      2092.0       506.0        129.0        112.0
#
#      Unnamed: 12  Unnamed: 13  Unnamed: 14  Unnamed: 15 Unnamed: 16  \
# 160          9.0          3.0          3.0          4.0           2
#
#     Unnamed: 17 Hijas e hijos nacidos vivos2 Unnamed: 19
# 160         402                       429306    1.130464

# %%
fec_cd.columns
# Out:
# Index(['Entidad federativa', 'Grupos quinquenales de edad',
#        'Población femenina de 12 años y más',
#        'Número de hijas e hijos nacidos vivos', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14',
#        'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Hijas e hijos nacidos vivos2', 'Unnamed: 19'],
#       dtype='object')

# %%
fec_cd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1 entries, 160 to 160
# Data columns (total 20 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Entidad federativa                     1 non-null      object
#  1   Grupos quinquenales de edad            1 non-null      object
#  2   Población femenina de 12 años y más    1 non-null      float64
#  3   Número de hijas e hijos nacidos vivos  1 non-null      float64
#  4   Unnamed: 4                             1 non-null      float64
#  5   Unnamed: 5                             1 non-null      float64
#  6   Unnamed: 6                             1 non-null      float64
#  7   Unnamed: 7                             1 non-null      float64
#  8   Unnamed: 8                             1 non-null      float64
#  9   Unnamed: 9                             1 non-null      float64
# ...

# %%
fec_cd
# Out:
#       Entidad federativa Grupos quinquenales de edad  \
# 160  09 Ciudad de México                  30-34 años
#
#      Población femenina de 12 años y más  \
# 160                             380163.0
#
#      Número de hijas e hijos nacidos vivos  Unnamed: 4  Unnamed: 5  \
# 160                               154240.0     86469.0     89825.0
#
#      Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 160     37803.0      8564.0      2092.0       506.0        129.0        112.0
#
#      Unnamed: 12  Unnamed: 13  Unnamed: 14  Unnamed: 15 Unnamed: 16  \
# 160          9.0          3.0          3.0          4.0           2
#
#     Unnamed: 17 Hijas e hijos nacidos vivos2 Unnamed: 19
# 160         402                       429306    1.130464

# %%
fec_cd.drop(columns=["Entidad federativa","Grupos quinquenales de edad"], inplace=True)
# Out:
# C:\Users\cynhe\AppData\Local\Temp\ipykernel_30656\3589520719.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fec_cd.drop(columns=["Entidad federativa","Grupos quinquenales de edad"], inplace=True)

# %%
fec_cd
# Out:
#      Población femenina de 12 años y más  \
# 160                             380163.0
#
#      Número de hijas e hijos nacidos vivos  Unnamed: 4  Unnamed: 5  \
# 160                               154240.0     86469.0     89825.0
#
#      Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 160     37803.0      8564.0      2092.0       506.0        129.0        112.0
#
#      Unnamed: 12  Unnamed: 13  Unnamed: 14  Unnamed: 15 Unnamed: 16  \
# 160          9.0          3.0          3.0          4.0           2
#
#     Unnamed: 17 Hijas e hijos nacidos vivos2 Unnamed: 19
# 160         402                       429306    1.130464

# %%
fec_cd.mean(axis=1)
# Out:
# 160    66090.72947
# dtype: float64

# %%
fec_cd.describe()
# Out:
#        Población femenina de 12 años y más  \
# count                                  1.0
# mean                              380163.0
# std                                    NaN
# min                               380163.0
# 25%                               380163.0
# 50%                               380163.0
# 75%                               380163.0
# max                               380163.0
#
#        Número de hijas e hijos nacidos vivos  Unnamed: 4  Unnamed: 5  \
# count                                    1.0         1.0         1.0
# mean                                154240.0     86469.0     89825.0
# std                                      NaN         NaN         NaN
# min                                 154240.0     86469.0     89825.0
# 25%                                 154240.0     86469.0     89825.0
# 50%                                 154240.0     86469.0     89825.0
# 75%                                 154240.0     86469.0     89825.0
# ...

# %%
#fec_cd.columns[:4].tolist()

# %%
#fec_cd.columns[18:].tolist()

# %%
#fec_piv=fec_cd.set_index(fec_cd.columns[:4].tolist()).stack().reset_index()
#fec_piv
